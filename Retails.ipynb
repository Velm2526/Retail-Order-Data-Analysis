# %%
import pandas as pd

file_path = r"C:\Users\Vel M\OneDrive\Documents\project 1\orders.csv"

# Read CSV into DataFrame
df = pd.read_csv(file_path)

# %%
import mysql.connector 
from sqlalchemy import create_engine

config={
    'user':'root',
    'password':'2526',
    'host':'127.0.0.1',
    'database':'Retail_order'
}

connection_string = f'mysql+mysqlconnector://{config["user"]}:{config["password"]}@{config["host"]}/{config["database"]}'
engine = create_engine(connection_string)
df.to_sql('RetailOrders', con=engine, if_exists='replace', index=False)


print("Data inserted successfully!")

print(config)
cursor=connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[3], line 13
#      11 connection_string = f'mysql+mysqlconnector://{config["user"]}:{config["password"]}@{config["host"]}/{config["database"]}'
#      12 engine = create_engine(connection_string)
# ---> 13 df.to_sql('RetailOrders', con=engine, if_exists='replace', index=False)
#      16 print("Data inserted successfully!")
#      18 print(config)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['Order Id'] = df['Order Id'].fillna(0)
df['Order Date'] = df['Order Date'].fillna(0)
df['Discount Percent'] = df['Discount Percent'].fillna(0)
df['Quantity'] = df['Quantity'].fillna(0)
df['List Price'] = df['List Price'].fillna(0)
df['cost price'] = df['cost price'].fillna(0)
df['Product Id'] = df['Product Id'].fillna(0)
df['Sub Category'] = df['Sub Category'].fillna(0)
df['Category'] = df['Category'].fillna(0)
df['Region'] = df['Region'].fillna(0)
df['Postal Code'] = df['Postal Code'].fillna(0)
df['State'] = df['State'].fillna(0)
df['City'] = df['City'].fillna(0)
df['Segment'] = df['Segment'].fillna(0)
df['Ship Mode'] = df['Ship Mode'].fillna(0)
df['Country'] = df['Country'].fillna(0)

# %%
df.columns = df.columns.str.lower()  
df.columns = df.columns.str.replace(' ', '_') 
df.columns = df.columns.str.replace(r'[^\w\s]', '', regex=True)

# %%
#discount
df['discount'] = df['list_price']*(df['discount_percent']/100)
#Sale price
df['sale_price'] = df['list_price']-df['discount']
#profit
df['profit'] = df['sale_price']-df['cost_price']

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sale_price          float64
# profit              float64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 from sqlalchemy import create_engine
# ----> 2 connection_string = f'mysql+mysqlconnector://{config["root"]}:{config["2526"]}@{config["127.0.0.1"]}/{config["Retail_order"]}'
#       3 engine = create_engine(connection_string)
#       4 df.to_sql('RetailOrders', con=engine, if_exists='replace', index=False)
#
# KeyError: 'root'
